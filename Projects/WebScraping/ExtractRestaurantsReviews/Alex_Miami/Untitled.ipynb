# %%
import pandas as pd

# %%
data = pd.read_csv("5 RoostersORDER ONLINE_reviews.csv")
data
# Out:
#                   Name  Stars  \
# 0    Mohamed Shan Shan      5
# 1                Marwa      4
# 2           Noor Essam      1
# 3                 Dina      4
# 4        Ahmed Youssef      1
# ..                 ...    ...
# 922               sara      5
# 923      Sohaila Tamer      5
# 924      mohamed dahab      5
# 925               mido      1
# 926      mohamed dahab      5
#
#                                                 Review
# 0                         مطعم محترم ومحافظ علي مستواه
# 1    الاكل كان جميل و حلو بس جاه متاخر و مكنش فيه ك...
# 2    جابلى تسمم والفراخ بايظة محدش ياكل منه تانى مع...
# 3                                   Order arrived late
# 4                                       الاكل وصل بارد
# ..                                                 ...
# 922  الاكل تحفه و بيوصل سخن جداً و نضيف ❤️❤️❤️❤️ و ...
# 923      مطعم حلو جدا وخدمه عاليه جدا والاكل جميل شكرا
# 924  والله من أروع ما يكون ساندوتش الميجا كبير وتحف...
# ...

# %%
new_data = data.drop_duplicates()

# %%
new_data
# Out:
#                   Name  Stars  \
# 0    Mohamed Shan Shan      5
# 1                Marwa      4
# 2           Noor Essam      1
# 3                 Dina      4
# 4        Ahmed Youssef      1
# ..                 ...    ...
# 922               sara      5
# 923      Sohaila Tamer      5
# 924      mohamed dahab      5
# 925               mido      1
# 926      mohamed dahab      5
#
#                                                 Review
# 0                         مطعم محترم ومحافظ علي مستواه
# 1    الاكل كان جميل و حلو بس جاه متاخر و مكنش فيه ك...
# 2    جابلى تسمم والفراخ بايظة محدش ياكل منه تانى مع...
# 3                                   Order arrived late
# 4                                       الاكل وصل بارد
# ..                                                 ...
# 922  الاكل تحفه و بيوصل سخن جداً و نضيف ❤️❤️❤️❤️ و ...
# 923      مطعم حلو جدا وخدمه عاليه جدا والاكل جميل شكرا
# 924  والله من أروع ما يكون ساندوتش الميجا كبير وتحف...
# ...
