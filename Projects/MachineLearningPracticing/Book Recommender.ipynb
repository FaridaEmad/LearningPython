# %% [markdown]
# # Book Recommender System Using Clustering | Collaborative Based

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors

# %%
books = pd.read_csv('BX-Books.csv', sep=";", on_bad_lines='skip', encoding="latin-1")
# Out:
# C:\Users\Farida\AppData\Local\Temp\ipykernel_3652\3258148588.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('BX-Books.csv', sep=";", on_bad_lines='skip', encoding="latin-1")

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
books = books[['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
        'Image-URL-L']]

# %%
books.head(2)
# Out:
#          ISBN           Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher                                        Image-URL-L
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...

# %%
books.rename(columns={
    "Book-Title":"Title",
    "Book-Author":"Author",
    "Year-Of-Publication":"Year",
    "Image-URL-L":"Img-URL"
},inplace=True)
# Out:
# C:\Users\Farida\AppData\Local\Temp\ipykernel_3652\2724345789.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books.rename(columns={

# %%
books.head(2)
# Out:
#          ISBN                Title                Author  Year  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford  2002
# 1  0002005018         Clara Callan  Richard Bruce Wright  2001
#
#                  Publisher                                            Img-URL
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...

# %%
users = pd.read_csv('BX-Users.csv', sep=";", on_bad_lines='skip', encoding="latin-1")

# %%
users
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
ratings = pd.read_csv('BX-Book-Ratings.csv', sep=";", on_bad_lines='skip', encoding="latin-1")

# %%
ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
books.shape,users.shape,ratings.shape
# Out:
# ((271360, 6), (278858, 3), (1149780, 3))

# %%
ratings.rename(columns={
    "User-ID":"User_ID",
    "Book-Rating":"Rating"
},inplace=True)

# %%
ratings
# Out:
#          User_ID         ISBN  Rating
# 0         276725   034545104X       0
# 1         276726   0155061224       5
# 2         276727   0446520802       0
# 3         276729   052165615X       3
# 4         276729   0521795028       6
# ...          ...          ...     ...
# 1149775   276704   1563526298       9
# 1149776   276706   0679447156       0
# 1149777   276709   0515107662      10
# 1149778   276721   0590442449      10
# 1149779   276723  05162443314       8
#
# [1149780 rows x 3 columns]

# %%
ratings['User_ID'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0          276725
# 1          276726
# 2          276727
# 3          276729
# 4          276729
#             ...
# 1149775    276704
# 1149776    276706
# 1149777    276709
# 1149778    276721
# 1149779    276723
# Name: User_ID, Length: 1149780, dtype: int64>

# %%
ratings['User_ID'].unique().shape
# Out:
# (105283,)

# %%
x = ratings['User_ID'].value_counts() > 200
x
# Out:
# User_ID
# 11676      True
# 198711     True
# 153662     True
# 98391      True
# 35859      True
#           ...
# 116180    False
# 116166    False
# 116154    False
# 116137    False
# 276723    False
# Name: count, Length: 105283, dtype: bool

# %%
x[x].shape
# Out:
# (899,)

# %%
y = x[x].index

# %%
y
# Out:
# Index([ 11676, 198711, 153662,  98391,  35859, 212898, 278418,  76352, 110973,
#        235105,
#        ...
#        260183,  73681,  44296, 155916,   9856, 274808,  28634,  59727, 268622,
#        188951],
#       dtype='int64', name='User_ID', length=899)

# %%
ratings = ratings[ratings['User_ID'].isin(y)]

# %%
ratings.head()
# Out:
#       User_ID        ISBN  Rating
# 1456   277427  002542730X      10
# 1457   277427  0026217457       0
# 1458   277427  003008685X       8
# 1459   277427  0030615321       0
# 1460   277427  0060002050       0

# %%
ratings.shape
# Out:
# (526356, 3)

# %%
ratingsWithBooks = ratings.merge(books, on="ISBN")

# %%
ratingsWithBooks.head()
# Out:
#    User_ID        ISBN  Rating  \
# 0   277427  002542730X      10
# 1   277427  0026217457       0
# 2   277427  003008685X       8
# 3   277427  0030615321       0
# 4   277427  0060002050       0
#
#                                                Title                 Author  \
# 0  Politically Correct Bedtime Stories: Modern Ta...      James Finn Garner
# 1                 Vegetarian Times Complete Cookbook             Lucy  Moll
# 2                                           Pioneers  James Fenimore Cooper
# 3   Ask for May, Settle for June (A Doonesbury book)          G. B. Trudeau
# 4                  On a Wicked Dawn (Cynster Novels)      Stephanie Laurens
#
#    Year                  Publisher  \
# 0  1994  John Wiley &amp; Sons Inc
# 1  1995      John Wiley &amp; Sons
# 2  1974           Thomson Learning
# 3  1982        Henry Holt &amp; Co
# 4  2002                 Avon Books
#
#                                              Img-URL
# ...

# %%
ratingsWithBooks.shape
# Out:
# (487671, 8)

# %%
numRatings = ratingsWithBooks.groupby('Title')['Rating'].count().reset_index()

# %%
numRatings.head()
# Out:
#                                                Title  Rating
# 0   A Light in the Storm: The Civil War Diary of ...       2
# 1                              Always Have Popsicles       1
# 2               Apple Magic (The Collector's series)       1
# 3   Beyond IBM: Leadership Marketing and Finance ...       1
# 4   Clifford Visita El Hospital (Clifford El Gran...       1

# %%
numRatings.rename(columns={"Rating":"numOfRatings"}, inplace=True)

# %%
numRatings.head()
# Out:
#                                                Title  numOfRatings
# 0   A Light in the Storm: The Civil War Diary of ...             2
# 1                              Always Have Popsicles             1
# 2               Apple Magic (The Collector's series)             1
# 3   Beyond IBM: Leadership Marketing and Finance ...             1
# 4   Clifford Visita El Hospital (Clifford El Gran...             1

# %%
finalRating = ratingsWithBooks.merge(numRatings,on="Title")

# %%
finalRating
# Out:
#         User_ID        ISBN  Rating  \
# 0        277427  002542730X      10
# 1        277427  0026217457       0
# 2        277427  003008685X       8
# 3        277427  0030615321       0
# 4        277427  0060002050       0
# ...         ...         ...     ...
# 487666   275970  1931868123       0
# 487667   275970  3411086211      10
# 487668   275970  3829021860       0
# 487669   275970  4770019572       0
# 487670   275970  9626340762       8
#
#                                                     Title  \
# 0       Politically Correct Bedtime Stories: Modern Ta...
# 1                      Vegetarian Times Complete Cookbook
# 2                                                Pioneers
# 3        Ask for May, Settle for June (A Doonesbury book)
# 4                       On a Wicked Dawn (Cynster Novels)
# ...                                                   ...
# 487666  There's a Porcupine in My Outhouse: Misadventu...
# ...

# %%
finalRating = finalRating[finalRating['numOfRatings']>=50]

# %%
finalRating.head()
# Out:
#     User_ID        ISBN  Rating  \
# 0    277427  002542730X      10
# 13   277427  0060930535       0
# 15   277427  0060934417       0
# 18   277427  0061009059       9
# 24   277427  006440188X       0
#
#                                                 Title  \
# 0   Politically Correct Bedtime Stories: Modern Ta...
# 13                      The Poisonwood Bible: A Novel
# 15                                 Bel Canto: A Novel
# 18  One for the Money (Stephanie Plum Novels (Pape...
# 24                                  The Secret Garden
#
#                      Author  Year                  Publisher  \
# 0         James Finn Garner  1994  John Wiley &amp; Sons Inc
# 13       Barbara Kingsolver  1999                  Perennial
# 15             Ann Patchett  2002                  Perennial
# 18          Janet Evanovich  1995                HarperTorch
# 24  Frances Hodgson Burnett  1998               HarperTrophy
#
# ...

# %%
finalRating.shape
# Out:
# (61853, 9)

# %%
finalRating.drop_duplicates(['User_ID','Title'], inplace=True)
# Out:
# C:\Users\Farida\AppData\Local\Temp\ipykernel_3652\4037443770.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   finalRating.drop_duplicates(['User_ID','Title'], inplace=True)

# %%
finalRating.shape
# Out:
# (59850, 9)

# %%
bookPivot = finalRating.pivot_table(columns='User_ID',index='Title',values='Rating')

# %%
bookPivot
# Out:
# User_ID                                             254     2276    2766    \
# Title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
bookPivot.fillna(0,inplace=True)

# %%
bookPivot
# Out:
# User_ID                                             254     2276    2766    \
# Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
bookSparce = csr_matrix(bookPivot)

# %%
bookSparce
# Out:
# <742x888 sparse matrix of type '<class 'numpy.float64'>'
# 	with 14961 stored elements in Compressed Sparse Row format>

# %%
model = NearestNeighbors(algorithm='brute')

# %%
model.fit(bookSparce)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
distance , suggestion = model.kneighbors(bookPivot.iloc[237,:].values.reshape(1,-1),n_neighbors=6)

# %%
distance
# Out:
# array([[ 0.        , 67.75691847, 68.05145112, 72.277244  , 75.81556568,
#         76.30203143]])

# %%
suggestion
# Out:
# array([[237, 238, 240, 241, 184, 536]], dtype=int64)

# %%
for i in range(len(suggestion)):
    print(bookPivot.index[suggestion[i]])
# Out:
# Index(['Harry Potter and the Chamber of Secrets (Book 2)',
#        'Harry Potter and the Goblet of Fire (Book 4)',
#        'Harry Potter and the Prisoner of Azkaban (Book 3)',
#        'Harry Potter and the Sorcerer's Stone (Book 1)', 'Exclusive',
#        'The Cradle Will Fall'],
#       dtype='object', name='Title')

# %%
bookPivot.index
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        '84 Charing Cross Road', 'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Cry In The Night',
#        ...
#        'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wizard and Glass (The Dark Tower, Book 4)', 'Wuthering Heights',
#        'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='Title', length=742)

# %%
booksName = bookPivot.index
